# %% [markdown]
# # Image classification with Vision Transformer
#
# **Author:** [Khalid Salama](https://www.linkedin.com/in/khalid-salama-24403144/)<br>
# **Date created:** 2021/01/18<br>
# **Last modified:** 2021/01/18<br>
# **Description:** Implementing the Vision Transformer (ViT) model for image classification.

# %% [markdown]
# ## Introduction
#
# This example implements the [Vision Transformer (ViT)](https://arxiv.org/abs/2010.11929)
# model by Alexey Dosovitskiy et al. for image classification,
# and demonstrates it on the CIFAR-100 dataset.
# The ViT model applies the Transformer architecture with self-attention to sequences of
# image patches, without using convolution layers.
#
# This example requires TensorFlow 2.4 or higher, as well as
# [TensorFlow Addons](https://www.tensorflow.org/addons/overview),
# which can be installed using the following command:
#
# ```python
# pip install -U tensorflow-addons
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 33.2 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %%
# !unzip "/content/drive/MyDrive/Meander_aug.zip" -d "/content/"

# %%
# import tensorflow as tf
# from tensorflow import keras
import matplotlib.pyplot as plt
import cv2
# import numpy as np
import os

# %%
data_path = '/content/content/Meanders'
categories = ['HealthyMeander', 'PatientMeander']
for category in categories:
  path = os.path.join(data_path, category)
  for img in os.listdir(path):
    img_array = cv2.imread(os.path.join(path, img))
    new_array = cv2.resize(img_array, (256, 256))
    plt.imshow(new_array, cmap='gray')
    # plt.show()
    break
  break

# %%
IMG_SIZE = 64

training_set = []

for category in categories:
  path = os.path.join(data_path, category)
  index = categories.index(category)
  for img in os.listdir(path):
    try:
      img_array = cv2.imread(os.path.join(path, img))
      new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
      training_set.append([new_array, index])
    except Exception as e:
        pass

# %%
import random
random.shuffle(training_set)

# %%
X_train = []
y_train = []

for img_array, label in training_set:
  X_train.append(img_array)
  y_train.append(label)

# %%
X_train =  np.array(X_train).reshape(-1,IMG_SIZE, IMG_SIZE, 3)
y_train = np.array(y_train)

# %%
# X_train = X_train/255.0

# %%
plt.imshow(X_train[0], cmap='gray')

# %%
X_train.shape
# Out:
# (264, 64, 64, 3)

# %%
y_train[:5]
# Out:
# array([1, 0, 0, 1, 1])

# %%
y_train = y_train.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ## Prepare the data

# %%
num_classes = 2
input_shape = (64, 64, 3)

# (x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (211, 64, 64, 3) - y_train shape: (211, 1)
# x_test shape: (53, 64, 64, 3) - y_test shape: (53, 1)

# %% [markdown]
# ## Configure the hyperparameters

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
num_epochs = 100
image_size = 72  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2

projection_dim = 64
num_heads = 4

transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %% [markdown]
# ## Use data augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        # layers.RandomZoom(
        #     height_factor=0.2, width_factor=0.2
        # ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %% [markdown]
# ## Implement multilayer perceptron (MLP)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ## Implement patch creation as a layer

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
# x_train[0]

# %% [markdown]
# Let's display patches for a sample image

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[0]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %% [markdown]
# ## Implement the patch encoding layer
#
# The `PatchEncoder` layer will linearly transform a patch by projecting it into a
# vector of size `projection_dim`. In addition, it adds a learnable position
# embedding to the projected vector.

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %% [markdown]
# ## Build the ViT model
#
# The ViT model consists of multiple Transformer blocks,
# which use the `layers.MultiHeadAttention` layer as a self-attention mechanism
# applied to the sequence of patches. The Transformer blocks produce a
# `[batch_size, num_patches, projection_dim]` tensor, which is processed via an
# classifier head with softmax to produce the final class probabilities output.
#
# Unlike the technique described in the [paper](https://arxiv.org/abs/2010.11929),
# which prepends a learnable embedding to the sequence of encoded patches to serve
# as the image representation, all the outputs of the final Transformer block are
# reshaped with `layers.Flatten()` and used as the image
# representation input to the classifier head.
# Note that the `layers.GlobalAveragePooling1D` layer
# could also be used instead to aggregate the outputs of the Transformer block,
# especially when the number of patches and the projection dimensions are large.

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %% [markdown]
# ## Compile, train, and evaluate the mode

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            # keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    # print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 15s 145ms/step - loss: 6.3823 - accuracy: 0.6243 - val_loss: 9.4701 - val_accuracy: 0.5909
# Epoch 2/100
# 24/24 [==============================] - 1s 46ms/step - loss: 6.9977 - accuracy: 0.6667 - val_loss: 7.6190 - val_accuracy: 0.5909
# Epoch 3/100
# 24/24 [==============================] - 1s 40ms/step - loss: 4.7277 - accuracy: 0.6984 - val_loss: 1.6233 - val_accuracy: 0.5909
# Epoch 4/100
# 24/24 [==============================] - 2s 76ms/step - loss: 3.2154 - accuracy: 0.7037 - val_loss: 1.0910 - val_accuracy: 0.6364
# Epoch 5/100
# 24/24 [==============================] - 2s 77ms/step - loss: 2.1021 - accuracy: 0.7619 - val_loss: 2.9981 - val_accuracy: 0.6818
# Epoch 6/100
# 24/24 [==============================] - 1s 41ms/step - loss: 2.1087 - accuracy: 0.7831 - val_loss: 3.1952 - val_accuracy: 0.5455
# Epoch 7/100
# 24/24 [==============================] - 1s 41ms/step - loss: 1.7865 - accuracy: 0.6984 - val_loss: 2.4082 - val_accuracy: 0.5909
# Epoch 8/100
# 24/24 [==============================] - 2s 76ms/step - loss: 1.3173 - accuracy: 0.7249 - val_loss: 0.8845 - val_accuracy: 0.8182
# Epoch 9/100
# 24/24 [==============================] - 1s 42ms/step - loss: 1.0885 - accuracy: 0.7725 - val_loss: 1.5226 - val_accuracy: 0.6364
# Epoch 10/100
# 24/24 [==============================] - 1s 41ms/step - loss: 1.0649 - accuracy: 0.7407 - val_loss: 1.6339 - val_accuracy: 0.5455
# Epoch 11/100
# 24/24 [==============================] - 1s 42ms/step - loss: 1.1119 - accuracy: 0.7672 - val_loss: 0.8879 - val_accuracy: 0.7273
# Epoch 12/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6222 - accuracy: 0.7672 - val_loss: 0.8987 - val_accuracy: 0.7273
# Epoch 13/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6439 - accuracy: 0.7460 - val_loss: 0.5227 - val_accuracy: 0.6364
# Epoch 14/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.5095 - accuracy: 0.7989 - val_loss: 0.4703 - val_accuracy: 0.7273
# Epoch 15/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4269 - accuracy: 0.7989 - val_loss: 0.5954 - val_accuracy: 0.6818
# Epoch 16/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4918 - accuracy: 0.7778 - val_loss: 0.7900 - val_accuracy: 0.6818
# Epoch 17/100
# 24/24 [==============================] - 1s 40ms/step - loss: 0.4108 - accuracy: 0.8148 - val_loss: 0.6260 - val_accuracy: 0.7273
# Epoch 18/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4402 - accuracy: 0.8095 - val_loss: 0.8988 - val_accuracy: 0.6818
# Epoch 19/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4639 - accuracy: 0.8095 - val_loss: 0.4835 - val_accuracy: 0.7273
# Epoch 20/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4492 - accuracy: 0.8307 - val_loss: 0.5768 - val_accuracy: 0.7273
# Epoch 21/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.3339 - accuracy: 0.8148 - val_loss: 0.5096 - val_accuracy: 0.7727
# Epoch 22/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4620 - accuracy: 0.8360 - val_loss: 0.8448 - val_accuracy: 0.7273
# Epoch 23/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4422 - accuracy: 0.8042 - val_loss: 0.4804 - val_accuracy: 0.7727
# Epoch 24/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4258 - accuracy: 0.8095 - val_loss: 0.4487 - val_accuracy: 0.7273
# Epoch 25/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.4012 - accuracy: 0.7989 - val_loss: 0.4869 - val_accuracy: 0.7273
# Epoch 26/100
# 24/24 [==============================] - 1s 44ms/step - loss: 0.3926 - accuracy: 0.7937 - val_loss: 0.5946 - val_accuracy: 0.6818
# Epoch 27/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3006 - accuracy: 0.8413 - val_loss: 0.4686 - val_accuracy: 0.8182
# Epoch 28/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.3932 - accuracy: 0.8148 - val_loss: 0.3603 - val_accuracy: 0.8182
# Epoch 29/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4007 - accuracy: 0.8201 - val_loss: 0.5636 - val_accuracy: 0.7273
# Epoch 30/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2718 - accuracy: 0.8677 - val_loss: 0.5903 - val_accuracy: 0.6818
# Epoch 31/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3026 - accuracy: 0.8571 - val_loss: 0.3966 - val_accuracy: 0.7727
# Epoch 32/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3386 - accuracy: 0.8730 - val_loss: 0.4405 - val_accuracy: 0.7727
# Epoch 33/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2974 - accuracy: 0.8624 - val_loss: 0.3431 - val_accuracy: 0.8182
# Epoch 34/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3506 - accuracy: 0.8466 - val_loss: 0.4301 - val_accuracy: 0.8182
# Epoch 35/100
# 24/24 [==============================] - 2s 73ms/step - loss: 0.2936 - accuracy: 0.8571 - val_loss: 0.3288 - val_accuracy: 0.8636
# Epoch 36/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.3461 - accuracy: 0.8307 - val_loss: 0.7018 - val_accuracy: 0.7727
# Epoch 37/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.3169 - accuracy: 0.8519 - val_loss: 0.5485 - val_accuracy: 0.8636
# Epoch 38/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3420 - accuracy: 0.8466 - val_loss: 0.5716 - val_accuracy: 0.7727
# Epoch 39/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3047 - accuracy: 0.8677 - val_loss: 0.7790 - val_accuracy: 0.7727
# Epoch 40/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2519 - accuracy: 0.8730 - val_loss: 0.6544 - val_accuracy: 0.8182
# Epoch 41/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2686 - accuracy: 0.8836 - val_loss: 0.7734 - val_accuracy: 0.7273
# Epoch 42/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.3727 - accuracy: 0.8571 - val_loss: 0.5402 - val_accuracy: 0.8182
# Epoch 43/100
# 24/24 [==============================] - 1s 40ms/step - loss: 0.3310 - accuracy: 0.8730 - val_loss: 0.4541 - val_accuracy: 0.7727
# Epoch 44/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3186 - accuracy: 0.8571 - val_loss: 0.3620 - val_accuracy: 0.8182
# Epoch 45/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3088 - accuracy: 0.8730 - val_loss: 0.4547 - val_accuracy: 0.7727
# Epoch 46/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2742 - accuracy: 0.8783 - val_loss: 0.4153 - val_accuracy: 0.7273
# Epoch 47/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2159 - accuracy: 0.9153 - val_loss: 0.5379 - val_accuracy: 0.7727
# Epoch 48/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2974 - accuracy: 0.8836 - val_loss: 0.4003 - val_accuracy: 0.8182
# Epoch 49/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2719 - accuracy: 0.9101 - val_loss: 0.6599 - val_accuracy: 0.7273
# Epoch 50/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3216 - accuracy: 0.8783 - val_loss: 0.6112 - val_accuracy: 0.8636
# Epoch 51/100
# 24/24 [==============================] - 1s 40ms/step - loss: 0.2401 - accuracy: 0.9048 - val_loss: 0.5720 - val_accuracy: 0.7727
# Epoch 52/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2027 - accuracy: 0.9259 - val_loss: 0.8931 - val_accuracy: 0.7727
# Epoch 53/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4490 - accuracy: 0.8254 - val_loss: 0.4624 - val_accuracy: 0.7727
# Epoch 54/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2283 - accuracy: 0.8942 - val_loss: 0.4700 - val_accuracy: 0.7273
# Epoch 55/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2095 - accuracy: 0.9048 - val_loss: 0.5678 - val_accuracy: 0.7727
# Epoch 56/100
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2031 - accuracy: 0.9101 - val_loss: 0.4763 - val_accuracy: 0.7727
# Epoch 57/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2336 - accuracy: 0.8836 - val_loss: 0.5479 - val_accuracy: 0.7273
# Epoch 58/100
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2456 - accuracy: 0.8889 - val_loss: 0.5766 - val_accuracy: 0.7727
# Epoch 59/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2745 - accuracy: 0.8783 - val_loss: 0.3678 - val_accuracy: 0.8636
# Epoch 60/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2074 - accuracy: 0.9259 - val_loss: 0.6690 - val_accuracy: 0.7273
# Epoch 61/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2487 - accuracy: 0.8995 - val_loss: 0.4422 - val_accuracy: 0.7273
# Epoch 62/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2101 - accuracy: 0.9101 - val_loss: 0.5906 - val_accuracy: 0.8636
# Epoch 63/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2859 - accuracy: 0.8730 - val_loss: 0.5116 - val_accuracy: 0.6818
# Epoch 64/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2029 - accuracy: 0.8995 - val_loss: 0.4416 - val_accuracy: 0.8182
# Epoch 65/100
# 24/24 [==============================] - 1s 40ms/step - loss: 0.2369 - accuracy: 0.8995 - val_loss: 0.6109 - val_accuracy: 0.8182
# Epoch 66/100
# 24/24 [==============================] - 2s 73ms/step - loss: 0.2194 - accuracy: 0.8889 - val_loss: 0.3162 - val_accuracy: 0.9545
# Epoch 67/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1891 - accuracy: 0.9259 - val_loss: 0.3304 - val_accuracy: 0.8636
# Epoch 68/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1354 - accuracy: 0.9471 - val_loss: 0.3959 - val_accuracy: 0.8636
# Epoch 69/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1353 - accuracy: 0.9418 - val_loss: 0.4876 - val_accuracy: 0.8636
# Epoch 70/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1863 - accuracy: 0.9206 - val_loss: 0.5979 - val_accuracy: 0.7727
# Epoch 71/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1777 - accuracy: 0.9153 - val_loss: 0.4164 - val_accuracy: 0.7727
# Epoch 72/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2168 - accuracy: 0.9206 - val_loss: 0.5726 - val_accuracy: 0.8182
# Epoch 73/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2056 - accuracy: 0.9259 - val_loss: 0.3881 - val_accuracy: 0.7727
# Epoch 74/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1842 - accuracy: 0.9153 - val_loss: 0.3706 - val_accuracy: 0.8182
# Epoch 75/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1870 - accuracy: 0.9312 - val_loss: 0.3491 - val_accuracy: 0.7727
# Epoch 76/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1177 - accuracy: 0.9577 - val_loss: 0.3324 - val_accuracy: 0.9091
# Epoch 77/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1792 - accuracy: 0.9418 - val_loss: 0.4599 - val_accuracy: 0.7727
# Epoch 78/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2042 - accuracy: 0.9259 - val_loss: 0.6230 - val_accuracy: 0.7727
# Epoch 79/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2244 - accuracy: 0.9259 - val_loss: 0.7109 - val_accuracy: 0.7727
# Epoch 80/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2334 - accuracy: 0.9048 - val_loss: 0.8962 - val_accuracy: 0.7273
# Epoch 81/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2643 - accuracy: 0.9259 - val_loss: 2.1743 - val_accuracy: 0.7727
# Epoch 82/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2205 - accuracy: 0.9365 - val_loss: 0.5970 - val_accuracy: 0.7273
# Epoch 83/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.2501 - accuracy: 0.8889 - val_loss: 0.5940 - val_accuracy: 0.7727
# Epoch 84/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1721 - accuracy: 0.9259 - val_loss: 0.6469 - val_accuracy: 0.7727
# Epoch 85/100
# 24/24 [==============================] - 1s 44ms/step - loss: 0.3000 - accuracy: 0.8677 - val_loss: 0.4914 - val_accuracy: 0.7727
# Epoch 86/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1350 - accuracy: 0.9206 - val_loss: 0.5850 - val_accuracy: 0.8182
# Epoch 87/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1703 - accuracy: 0.9206 - val_loss: 0.9317 - val_accuracy: 0.7727
# Epoch 88/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1475 - accuracy: 0.9365 - val_loss: 0.5669 - val_accuracy: 0.7727
# Epoch 89/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2451 - accuracy: 0.9206 - val_loss: 0.6341 - val_accuracy: 0.8182
# Epoch 90/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1549 - accuracy: 0.9365 - val_loss: 0.6969 - val_accuracy: 0.7727
# Epoch 91/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1588 - accuracy: 0.9312 - val_loss: 0.3936 - val_accuracy: 0.8182
# Epoch 92/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1547 - accuracy: 0.9206 - val_loss: 0.4443 - val_accuracy: 0.9091
# Epoch 93/100
# 24/24 [==============================] - 1s 40ms/step - loss: 0.1439 - accuracy: 0.9312 - val_loss: 0.5409 - val_accuracy: 0.8182
# Epoch 94/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1662 - accuracy: 0.9153 - val_loss: 0.5001 - val_accuracy: 0.7727
# Epoch 95/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2573 - accuracy: 0.9577 - val_loss: 0.7072 - val_accuracy: 0.7273
# Epoch 96/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1750 - accuracy: 0.9259 - val_loss: 0.5053 - val_accuracy: 0.8182
# Epoch 97/100
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1547 - accuracy: 0.9312 - val_loss: 0.3201 - val_accuracy: 0.9091
# Epoch 98/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1140 - accuracy: 0.9735 - val_loss: 0.5673 - val_accuracy: 0.8182
# Epoch 99/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2639 - accuracy: 0.9048 - val_loss: 0.6536 - val_accuracy: 0.8182
# Epoch 100/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2164 - accuracy: 0.9259 - val_loss: 0.5610 - val_accuracy: 0.7727
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5282 - accuracy: 0.8302
# Test accuracy: 83.02%

# %% [markdown]
# After 100 epochs, the ViT model achieves around 55% accuracy and
# 82% top-5 accuracy on the test data. These are not competitive results on the CIFAR-100 dataset,
# as a ResNet50V2 trained from scratch on the same data can achieve 67% accuracy.
#
# Note that the state of the art results reported in the
# [paper](https://arxiv.org/abs/2010.11929) are achieved by pre-training the ViT model using
# the JFT-300M dataset, then fine-tuning it on the target dataset. To improve the model quality
# without pre-training, you can try to train the model for more epochs, use a larger number of
# Transformer layers, resize the input images, change the patch size, or increase the projection dimensions.
# Besides, as mentioned in the paper, the quality of the model is affected not only by architecture choices,
# but also by parameters such as the learning rate schedule, optimizer, weight decay, etc.
# In practice, it's recommended to fine-tune a ViT model
# that was pre-trained using a large, high-resolution dataset.
